# %% [markdown]
# # Building Nested Domains with CstarSpecEngine
#
# This notebook demonstrates how to use `CstarSpecEngine` to build nested domains.

# %% [markdown]
# ## Setup
#
# Enable autoreload for development and import the package.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Generate All Domains
#
# Create a `CstarSpecEngine` instance and generate all domains from `domains.yml`.
#
# **Parameters:**
# - `clobber_inputs`: If `True`, overwrite existing input files for all domains
# - `clobber_source_data`: If `True`, re-download source datasets
# - `partition_files`: If `True`, partition input files across tiles
# - `test`: If `True`, truncate generation loop after 2 iterations (for testing)
# - `compile_time_settings`: Optional dict of compile-time settings overrides
# - `run_time_settings`: Optional dict of run-time settings overrides
# - `overrides`: Optional dict of configuration overrides to apply to all domains
#
# The method returns a dictionary mapping domain names to `CstarSpecBuilder` instances.

# %%
import cson_forge

# %% [markdown]
# ## Run All Simulations
#
# Execute model simulations for all generated domains. The `run_all()` method handles execution for all builders and returns execution handlers for monitoring the runs.
#
# **Note:** This cell is commented out by default. Uncomment to run all simulations.

# %%
engine = cson_forge.CstarSpecEngine(domains_file="domains-nested.yml")
builders = engine.generate_all(clobber_inputs=False, stop_on_failure=True)
# Out:
# ================================================================================
# Starting generation for 3 domain(s)
# ================================================================================
#
#
# --------------------------------------------------------------------------------
# [1/3] Processing domain: GoA-10th_deg
# --------------------------------------------------------------------------------
# ⚠ Removed ~/.cache/cstar to avoid stale C-Star cache between runs
# /var/folders/x8/7n8hknbj717fxnf07pnk3pch0000gn/T/ipykernel_65111/3948763449.py:2: UserWarning: ~/.cache/cstar was removed to avoid stale cache state
#   builders = engine.generate_all(clobber_inputs=False, stop_on_failure=True)
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_GoA-10th_deg_20120101.nc
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_GoA-10th_deg_20120102.nc
# ✔️  TPXO dataset verified at: /Users/mclong/cson-forge-data/source-data/TPXO/TPXO10.v2
# ✔️  Using existing BGC dataset: /Users/mclong/cson-forge-data/source-data/UNIFIED_BGC/BGCdataset.nc
# ℹ️  Using existing blueprint from file: B_cson_roms-marbl_v0.1_GoA-10th_deg_128procs_postconfig.yml
# 2026-02-14 00:28:35,852 [INFO] - simulation.py:1200 - 🛠️ Configuring ROMSSimulation
# 2026-02-14 00:28:35,853 [INFO] - simulation.py:1203 - 🔧 Setting up ROMSExternalCodeBase...
# 2026-02-14 00:28:49,307 [INFO] - simulation.py:1203 - 🔧 Setting up MARBLExternalCodeBase...
# 2026-02-14 00:29:09,160 [INFO] - simulation.py:1217 - 📦 Fetching compile-time code...
# 2026-02-14 00:29:09,169 [INFO] - simulation.py:1222 - 📦 Fetching runtime code...
# 2026-02-14 00:29:09,171 [INFO] - simulation.py:1227 - 📦 Fetching input datasets...
# 2026-02-14 00:29:24,868 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_grid.nc into (16,8)
# 2026-02-14 00:29:26,454 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_initial_conditions.nc into (16,8)
# 2026-02-14 00:29:31,476 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_tidal.nc into (16,8)
# 2026-02-14 00:29:32,475 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_river.nc into (16,8)
# 2026-02-14 00:29:33,538 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_surface-physics_201112.nc into (16,8)
# 2026-02-14 00:29:34,470 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_surface-physics_201201.nc into (16,8)
# 2026-02-14 00:29:35,560 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_surface-bgc_clim.nc into (16,8)
#
# ✓ Successfully completed domain: GoA-10th_deg
#
# --------------------------------------------------------------------------------
# [2/3] Processing domain: NEP-4th_deg
# --------------------------------------------------------------------------------
# ⚠ Removed ~/.cache/cstar to avoid stale C-Star cache between runs
# /var/folders/x8/7n8hknbj717fxnf07pnk3pch0000gn/T/ipykernel_65111/3948763449.py:2: UserWarning: ~/.cache/cstar was removed to avoid stale cache state
#   builders = engine.generate_all(clobber_inputs=False, stop_on_failure=True)
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_NEP-4th_deg_20120101.nc
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_NEP-4th_deg_20120102.nc
# ✔️  TPXO dataset verified at: /Users/mclong/cson-forge-data/source-data/TPXO/TPXO10.v2
# ✔️  Using existing BGC dataset: /Users/mclong/cson-forge-data/source-data/UNIFIED_BGC/BGCdataset.nc
# ℹ️  Using existing blueprint from file: B_cson_roms-marbl_v0.1_NEP-4th_deg_128procs_postconfig.yml
# 2026-02-14 00:32:55,593 [INFO] - simulation.py:1200 - 🛠️ Configuring ROMSSimulation
# 2026-02-14 00:32:55,594 [INFO] - simulation.py:1203 - 🔧 Setting up ROMSExternalCodeBase...
# 2026-02-14 00:33:08,792 [INFO] - simulation.py:1203 - 🔧 Setting up MARBLExternalCodeBase...
# 2026-02-14 00:33:29,231 [INFO] - simulation.py:1217 - 📦 Fetching compile-time code...
# 2026-02-14 00:33:29,240 [INFO] - simulation.py:1222 - 📦 Fetching runtime code...
# 2026-02-14 00:33:29,242 [INFO] - simulation.py:1227 - 📦 Fetching input datasets...
# 2026-02-14 00:33:44,594 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_grid.nc into (16,8)
# 2026-02-14 00:33:46,133 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_initial_conditions.nc into (16,8)
# 2026-02-14 00:33:50,918 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_tidal.nc into (16,8)
# 2026-02-14 00:33:51,893 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_river.nc into (16,8)
# 2026-02-14 00:33:52,944 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_surface-physics_201112.nc into (16,8)
# 2026-02-14 00:33:53,881 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_surface-physics_201201.nc into (16,8)
# 2026-02-14 00:33:55,116 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_NEP-4th_deg_128procs_surface-bgc_clim.nc into (16,8)
#
# ✓ Successfully completed domain: NEP-4th_deg
#
# --------------------------------------------------------------------------------
# [3/3] Processing domain: PAC_2fth_deg
# --------------------------------------------------------------------------------
# ⚠ Removed ~/.cache/cstar to avoid stale C-Star cache between runs
# /var/folders/x8/7n8hknbj717fxnf07pnk3pch0000gn/T/ipykernel_65111/3948763449.py:2: UserWarning: ~/.cache/cstar was removed to avoid stale cache state
#   builders = engine.generate_all(clobber_inputs=False, stop_on_failure=True)
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_PAC_2fth_deg_20120101.nc
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_PAC_2fth_deg_20120102.nc
# ✔️  TPXO dataset verified at: /Users/mclong/cson-forge-data/source-data/TPXO/TPXO10.v2
# ✔️  Using existing BGC dataset: /Users/mclong/cson-forge-data/source-data/UNIFIED_BGC/BGCdataset.nc
# ℹ️  Using existing blueprint from file: B_cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_postconfig.yml
# 2026-02-14 00:35:39,625 [INFO] - simulation.py:1200 - 🛠️ Configuring ROMSSimulation
# 2026-02-14 00:35:39,627 [INFO] - simulation.py:1203 - 🔧 Setting up ROMSExternalCodeBase...
# 2026-02-14 00:35:53,680 [INFO] - simulation.py:1203 - 🔧 Setting up MARBLExternalCodeBase...
# 2026-02-14 00:36:14,681 [INFO] - simulation.py:1217 - 📦 Fetching compile-time code...
# 2026-02-14 00:36:14,691 [INFO] - simulation.py:1222 - 📦 Fetching runtime code...
# 2026-02-14 00:36:14,693 [INFO] - simulation.py:1227 - 📦 Fetching input datasets...
# 2026-02-14 00:36:31,658 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_grid.nc into (16,8)
# 2026-02-14 00:36:33,501 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_initial_conditions.nc into (16,8)
# 2026-02-14 00:36:38,346 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_tidal.nc into (16,8)
# 2026-02-14 00:36:39,364 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_river.nc into (16,8)
# 2026-02-14 00:36:40,636 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_boundary-physics_201201.nc into (16,8)
# 2026-02-14 00:36:43,001 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_boundary-bgc_clim.nc into (16,8)
# 2026-02-14 00:36:54,218 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_surface-physics_201112.nc into (16,8)
# 2026-02-14 00:36:55,142 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_surface-physics_201201.nc into (16,8)
# 2026-02-14 00:36:56,719 [INFO] - input_dataset.py:223 - Partitioning /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_PAC_2fth_deg_128procs_surface-bgc_clim.nc into (16,8)
#
# ✓ Successfully completed domain: PAC_2fth_deg
#
# ================================================================================
# Completed generation for all 3 domain(s)
# ================================================================================

# %%
exec_handlers = engine.run_all()    
for key, exec_handler in exec_handlers.items():
    print("-" * 100)
    print(key)
    print(exec_handler)
    print()
# Out:
# ================================================================================
# Starting execution for 3 domain(s)
# ================================================================================
#
#
# --------------------------------------------------------------------------------
# [1/3] Running simulation: GoA-10th_deg
# --------------------------------------------------------------------------------
# 2026-02-14 00:36:58,025 [INFO] - simulation.py:1556 - Running mpirun -n 128 /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_20120101-20120102/input/compile_time_code/roms /Users/mclong/cson-forge-data/cson-forge-run/cson_roms-marbl_v0.1_GoA-10th_deg_128procs_20120101-20120102/input/runtime_code/cson_roms-marbl_v0.1_GoA-10th_deg_128procs.in
# Monitoring execution status for GoA-10th_deg...
#   Status: running
#   Status: running
#   Status: running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 exec_handlers = engine.run_all()
#       2 for key, exec_handler in exec_handlers.items():
#       3     print("-" * 100)
#
# File ~/codes/cson-forge/cson_forge/_core.py:2721, in run_all(self, poll_interval)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:

# %%
for key, exec_handler in exec_handlers.items():
    while not handler.ExecutionStatus.is_terminal(exec_handler.status):
        print("...", end="", flush=True)
        time.sleep(30)

    if exec_handler.status == handler.ExecutionStatus.COMPLETED:
        ocn.post_run()
    else:
        raise Exception("Model run failed")
