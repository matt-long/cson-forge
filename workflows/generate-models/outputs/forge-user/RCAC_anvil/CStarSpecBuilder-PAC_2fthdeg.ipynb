# %% [markdown]
# # Making a new domain: `CStarSpecBuilder`
#
# This notebook demonstrates how to create a new domain and run a ROMS simulation using C-SON Forge.

# %% [markdown]
# ## Setup
#
# First, import the necessary modules and define the domain configuration parameters.

# %%
# %load_ext autoreload
# %autoreload 2

import cson_forge
import cstar.execution.handler as handler
import time
from datetime import datetime 

grid_name = "PAC_2fth_deg"
model_name = "cson_roms-marbl_v0.1"
start_time = datetime(2012, 1, 1)
end_time = datetime(2012, 1, 2)

grid_kwargs = dict[str, float](
    nx=208,
    ny=192,
    size_x=1460*5,
    size_y=2220*5,
    center_lon=-165,
    center_lat=40,
    rot=-90,
    N=10,  # number of vertical levels
    theta_s=6.0,  # surface control parameter
    theta_b=3.0,  # bottom control parameter
    hc=250.0,  # critical depth
)

boundaries={
        "south": True,
        "east": False,
        "north": True,
        "west": True, 
    }

partitioning = {
    "n_procs_x": 16, # number of partitions in xi (x) 
    "n_procs_y": 8, # number of partitions in eta (y) 
}
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /anvil/projects/x-ees250129/x-awyatt1/.conda-env/share/proj failed

# %% [markdown]
# ## Initialize CstarSpecBuilder
#
# Create a `CstarSpecBuilder` instance with the domain configuration. This initializes the PRECONFIG stage, creating the grid object and blueprint structure.

# %%
ocn = cson_forge.CstarSpecBuilder(
    description="Test PAC",
    model_name=model_name,
    grid_name=grid_name,
    grid_kwargs=grid_kwargs,
    open_boundaries=boundaries,    
    start_time=start_time,
    end_time=end_time,
    partitioning=partitioning,
)

# %% [markdown]
# ### Visualize the grid

# %%
ocn.grid.plot()

# %% [markdown]
# ## Prepare Source Data
#
# Ensure that all required source datasets (GLORYS, UNIFIED, SRTM15, etc.) are staged locally. This downloads and prepares the data needed for input generation.

# %%
# ensure that source data is staged locally
ocn.ensure_source_data(clobber=False)
# Out:
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_PAC_2fth_deg_20120101.nc
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_PAC_2fth_deg_20120102.nc
# ✔️  TPXO dataset verified at: /anvil/projects/x-ees250129/cson-forge-data/source-data/TPXO/TPXO10.v2
# ✔️  Using existing BGC dataset: /anvil/projects/x-ees250129/cson-forge-data/source-data/UNIFIED_BGC/BGCdataset.nc

# %% [markdown]
# ## Generate Input Files
#
# Generate all model input files (grid, initial conditions, forcing) from the source data. This completes the POSTCONFIG stage and updates the blueprint with actual file paths.
#
# The system will look for an existing blueprint and, if a match is found, it will use that data unless the user sets `clobber=True` to force re-generating the data.

# %%
# prepare model input
ocn.generate_inputs(clobber=True) # setting clobber=True will overwrite existing files
# Out:
# ⚠️  Clobber=True: removing 8 existing .nc files in /anvil/projects/x-ees250129/cson-forge-data/input-data/cson_roms-marbl_v0.1_PAC_2fth_deg...
#
# ▶️  [1/8] Writing ROMS grid...
#
# ▶️  [2/8] Generating initial conditions...
# [########################################] | 100% Completed | 66.35 ss
#
# ▶️  [3/8] Generating surface forcing...
# [########################################] | 100% Completed | 10.47 ss
#
# ▶️  [4/8] Generating surface forcing...
# [########################################] | 100% Completed | 102.90 ms
#
# ▶️  [5/8] Generating boundary forcing...
# [WARNING] The southern boundary is divided by land. It would be safer (but slower and more memory-intensive) to use `apply_2d_horizontal_fill = True`.
# [########################################] | 100% Completed | 1.94 sms
#
# ▶️  [6/8] Generating boundary forcing...
# [########################################] | 100% Completed | 23.37 s
#
# ▶️  [7/8] Generating tidal forcing...
# [########################################] | 100% Completed | 11.03 ss
#
# ▶️  [8/8] Generating river forcing...
#
# ✅ All input files generated.
# /anvil/projects/x-ees250129/x-awyatt1/.conda-env/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `ROMSCompositeCodeRepository` - serialized value may not be as expected [field_name='code', input_value={'roms': {'documentation'...h': '', 'filter': None}}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `Dataset` - serialized value may not be as expected [field_name='initial_conditions', input_value={'documentation': '', 'lo... 'partitioned': False}]}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `Dataset` - serialized value may not be as expected [field_name='grid', input_value={'documentation': '', 'lo... 'partitioned': False}]}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `ForcingConfiguration` - serialized value may not be as expected [field_name='forcing', input_value={'boundary': {'documentat...]}, 'corrections': None}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `PartitioningParameterSet` - serialized value may not be as expected [field_name='partitioning', input_value={'documentation': '', 'lo..._x': 16, 'n_procs_y': 8}, input_type=dict])
#   return self.__pydantic_serializer__.to_python(
# RomsMarblBlueprint(name='cson_roms-marbl_v0.1_PAC_2fth_deg', description='Test PAC', application=<Application.ROMS_MARBL: 'roms_marbl'>, state=<BlueprintState.NotSet: 'notset'>, valid_start_date=datetime.datetime(2012, 1, 1, 0, 0), valid_end_date=datetime.datetime(2012, 1, 2, 0, 0), code={'roms': {'documentation': '', 'locked': False, 'location': 'https://github.com/CWorthy-ocean/ucla-roms.git', 'commit': '84f4ee7886e9ee4c33b3248b35c955551f3b9c06', 'branch': '', 'filter': None}, 'run_time': {'documentation': '', 'locked': False, 'location': 'placeholder://run_time', 'commit': '', 'branch': 'main', 'filter': None}, 'compile_time': {'documentation': '', 'locked': False, 'location': 'placeholder://compile_time', 'commit': '', 'branch': 'main', 'filter': None}, 'marbl': {'documentation': '', 'locked': False, 'location': 'https://github.com/marbl-ecosys/MARBL.git', 'commit': 'marbl0.45.0', 'branch': '', 'filter': None}}, initial_conditions={'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/anvil/projects/x-ees250129/cson-forge-data/input-data/cson_roms-marbl_v0.1_PAC_2fth_deg/cson_roms-marbl_v0.1_PAC_2fth_deg_initial_conditions.nc'), 'partitioned': False}]}, grid={'documentation': '', 'locked': False, 'data': [{'location': '/anvil/projects/x-ees250129/cson-forge-data/input-data/cson_roms-marbl_v0.1_PAC_2fth_deg/cson_roms-marbl_v0.1_PAC_2fth_deg_grid.nc', 'partitioned': False}]}, forcing={'boundary': {'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/anvil/projects/x-ees250129/cson-forge-data/input-data/cson_roms-marbl_v0.1_PAC_2fth_deg/cson_roms-marbl_v0.1_PAC_2fth_deg_boundary-physics_201201.nc'), 'partitioned': False}, {'location': PosixPath('/anvil/projects/x-ees250129/cson-forge-data/input-data/cson_roms-marbl_v0.1_PAC_2fth_deg/cson_roms-marbl_v0.1_PAC_2fth_deg_boundary-bgc_clim.nc'), 'partitioned': False}]}, 'surface': {'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/anvil/projects/x-ees250129/cson-forge-data/input-data/cson_roms-marbl_v0.1_PAC_2fth_deg/cson_roms-marbl_v0.1_PAC_2fth_deg_surface-physics_201201.nc'), 'partitioned': False}, {'location': PosixPath('/anvil/projects/x-ees250129/cson-forge-data/input-data/cson_roms-marbl_v0.1_PAC_2fth_deg/cson_roms-marbl_v0.1_PAC_2fth_deg_surface-bgc_clim.nc'), 'partitioned': False}]}, 'tidal': {'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/anvil/projects/x-ees250129/cson-forge-data/input-data/cson_roms-marbl_v0.1_PAC_2fth_deg/cson_roms-marbl_v0.1_PAC_2fth_deg_tidal.nc'), 'partitioned': False}]}, 'river': {'documentation': '', 'locked': False, 'data': [{'location': PosixPath('/anvil/projects/x-ees250129/cson-forge-data/input-data/cson_roms-marbl_v0.1_PAC_2fth_deg/cson_roms-marbl_v0.1_PAC_2fth_deg_river.nc'), 'partitioned': False}]}, 'corrections': None}, partitioning={'documentation': '', 'locked': False, 'hash': None, 'n_procs_x': 16, 'n_procs_y': 8}, model_params=None, runtime_params=None, cdr_forcing=None)

# %% [markdown]
# ## Access Generated Input Datasets
#
# Input datasets are available on the `datasets` attribute of the `CstarSpecBuilder` after `generate_inputs()` has completed. The `datasets` dictionary only contains keys for fields that exist in the blueprint and have been successfully generated.
#
# **Note:** Datasets are only available after `generate_inputs()` has run and populated the blueprint with actual file paths. If a key doesn't exist, it means that field wasn't generated or isn't in the blueprint.

# %%
for key in ocn.datasets.keys():
    print("-"*100)
    print(key)
    print(ocn.datasets[key])
# Out:
# ----------------------------------------------------------------------------------------------------
# grid
# <xarray.Dataset> Size: 4MB
# Dimensions:       (eta_rho: 194, xi_rho: 210, xi_u: 209, eta_v: 193,
#                    eta_coarse: 98, xi_coarse: 106, s_rho: 10, s_w: 11)
# Coordinates:
#     lat_rho       (eta_rho, xi_rho) float64 326kB ...
#     lon_rho       (eta_rho, xi_rho) float64 326kB ...
#     lat_u         (eta_rho, xi_u) float64 324kB ...
#     lon_u         (eta_rho, xi_u) float64 324kB ...
#     lat_v         (eta_v, xi_rho) float64 324kB ...
#     lon_v         (eta_v, xi_rho) float64 324kB ...
#     lat_coarse    (eta_coarse, xi_coarse) float64 83kB ...
#     lon_coarse    (eta_coarse, xi_coarse) float64 83kB ...
# Dimensions without coordinates: eta_rho, xi_rho, xi_u, eta_v, eta_coarse,
#                                 xi_coarse, s_rho, s_w
# Data variables: (12/15)
#     angle         (eta_rho, xi_rho) float64 326kB ...
#     f             (eta_rho, xi_rho) float64 326kB ...
#     pm            (eta_rho, xi_rho) float64 326kB ...
#     pn            (eta_rho, xi_rho) float64 326kB ...
#     spherical     |S1 1B ...
#     mask_rho      (eta_rho, xi_rho) int32 163kB ...
#     ...            ...
#     mask_coarse   (eta_coarse, xi_coarse) int32 42kB ...
#     h             (eta_rho, xi_rho) float64 326kB ...
#     sigma_r       (s_rho) float32 40B ...
#     Cs_r          (s_rho) float32 40B ...
#     sigma_w       (s_w) float32 44B ...
#     Cs_w          (s_w) float32 44B ...
# Attributes: (12/13)
#     title:                   ROMS grid created by ROMS-Tools
#     roms_tools_version:      3.3.0
#     size_x:                  7300
#     size_y:                  11100
#     center_lon:              -165
#     center_lat:              40
#     ...                      ...
#     straddle:                False
#     topography_source_name:  ETOPO5
#     hmin:                    5.0
#     theta_s:                 6.0
#     theta_b:                 3.0
#     hc:                      250.0
# ----------------------------------------------------------------------------------------------------
# initial_conditions
# <xarray.Dataset> Size: 61MB
# Dimensions:      (ocean_time: 1, s_rho: 10, eta_rho: 194, xi_rho: 210,
#                   xi_u: 209, eta_v: 193, s_w: 11)
# Coordinates:
#     abs_time     (ocean_time) datetime64[ns] 8B ...
#   * ocean_time   (ocean_time) float64 8B 3.787e+08
# Dimensions without coordinates: s_rho, eta_rho, xi_rho, xi_u, eta_v, s_w
# Data variables: (12/42)
#     temp         (ocean_time, s_rho, eta_rho, xi_rho) float32 2MB ...
#     salt         (ocean_time, s_rho, eta_rho, xi_rho) float32 2MB ...
#     u            (ocean_time, s_rho, eta_rho, xi_u) float32 2MB ...
#     v            (ocean_time, s_rho, eta_v, xi_rho) float32 2MB ...
#     zeta         (ocean_time, eta_rho, xi_rho) float32 163kB ...
#     ubar         (ocean_time, eta_rho, xi_u) float32 162kB ...
#     ...           ...
#     Lig          (ocean_time, s_rho, eta_rho, xi_rho) float32 2MB ...
#     DIC_ALT_CO2  (ocean_time, s_rho, eta_rho, xi_rho) float32 2MB ...
#     ALK_ALT_CO2  (ocean_time, s_rho, eta_rho, xi_rho) float32 2MB ...
#     w            (ocean_time, s_w, eta_rho, xi_rho) float32 2MB ...
#     Cs_r         (s_rho) float32 40B ...
#     Cs_w         (s_w) float32 44B ...
# Attributes:
#     title:                                ROMS initial conditions file create...
#     roms_tools_version:                   3.3.0
#     ini_time:                             2012-01-01 00:00:00
#     model_reference_date:                 2000-01-01 00:00:00
#     adjust_depth_for_sea_surface_height:  False
#     source:                               GLORYS
#     bgc_source:                           UNIFIED
#     theta_s:                              6.0
#     theta_b:                              3.0
#     hc:                                   250.0
# ----------------------------------------------------------------------------------------------------
# forcing.surface
# [<xarray.Dataset> Size: 29MB
# Dimensions:   (time: 25, eta_rho: 194, xi_rho: 210)
# Coordinates:
#     abs_time  (time) datetime64[ns] 200B ...
#   * time      (time) float64 200B 4.383e+03 4.383e+03 ... 4.384e+03 4.384e+03
# Dimensions without coordinates: eta_rho, xi_rho
# Data variables:
#     uwnd      (time, eta_rho, xi_rho) float32 4MB ...
#     vwnd      (time, eta_rho, xi_rho) float32 4MB ...
#     swrad     (time, eta_rho, xi_rho) float32 4MB ...
#     lwrad     (time, eta_rho, xi_rho) float32 4MB ...
#     Tair      (time, eta_rho, xi_rho) float32 4MB ...
#     rain      (time, eta_rho, xi_rho) float32 4MB ...
#     qair      (time, eta_rho, xi_rho) float32 4MB ...
# Attributes:
#     title:                 ROMS surface forcing file created by ROMS-Tools
#     roms_tools_version:    3.3.0
#     start_time:            2012-01-01 00:00:00
#     end_time:              2012-01-02 00:00:00
#     source:                ERA5
#     correct_radiation:     True
#     wind_dropoff:          False
#     use_coarse_grid:       False
#     model_reference_date:  2000-01-01 00:00:00
#     type:                  physics, <xarray.Dataset> Size: 12MB
# Dimensions:       (time: 12, eta_rho: 194, xi_rho: 210)
# Coordinates:
#     month         (time) int32 48B ...
#     abs_time      (time) datetime64[ns] 96B ...
#     pco2_time     (time) float64 96B ...
#     iron_time     (time) float64 96B ...
#     dust_time     (time) float64 96B ...
#     nox_time      (time) float64 96B ...
#     nhy_time      (time) float64 96B ...
# Dimensions without coordinates: time, eta_rho, xi_rho
# Data variables:
#     pco2_air      (time, eta_rho, xi_rho) float32 2MB ...
#     dust          (time, eta_rho, xi_rho) float32 2MB ...
#     iron          (time, eta_rho, xi_rho) float32 2MB ...
#     nox           (time, eta_rho, xi_rho) float32 2MB ...
#     nhy           (time, eta_rho, xi_rho) float32 2MB ...
#     pco2_air_alt  (time, eta_rho, xi_rho) float32 2MB ...
# Attributes:
#     title:                 ROMS surface forcing file created by ROMS-Tools
#     roms_tools_version:    3.3.0
#     start_time:            2012-01-01 00:00:00
#     end_time:              2012-01-02 00:00:00
#     source:                UNIFIED
#     correct_radiation:     False
#     wind_dropoff:          False
#     use_coarse_grid:       False
#     model_reference_date:  2000-01-01 00:00:00
#     type:                  bgc
#     climatology:           True]
# ----------------------------------------------------------------------------------------------------
# forcing.boundary
# [<xarray.Dataset> Size: 211kB
# Dimensions:     (bry_time: 2, s_rho: 10, xi_u: 209, xi_rho: 210, eta_rho: 194,
#                  eta_v: 193)
# Coordinates:
#     abs_time    (bry_time) datetime64[ns] 16B ...
#   * bry_time    (bry_time) float64 16B 4.383e+03 4.384e+03
# Dimensions without coordinates: s_rho, xi_u, xi_rho, eta_rho, eta_v
# Data variables: (12/21)
#     u_north     (bry_time, s_rho, xi_u) float32 17kB ...
#     v_north     (bry_time, s_rho, xi_rho) float32 17kB ...
#     temp_north  (bry_time, s_rho, xi_rho) float32 17kB ...
#     salt_north  (bry_time, s_rho, xi_rho) float32 17kB ...
#     zeta_north  (bry_time, xi_rho) float32 2kB ...
#     ubar_north  (bry_time, xi_u) float32 2kB ...
#     ...          ...
#     v_west      (bry_time, s_rho, eta_v) float32 15kB ...
#     temp_west   (bry_time, s_rho, eta_rho) float32 16kB ...
#     salt_west   (bry_time, s_rho, eta_rho) float32 16kB ...
#     zeta_west   (bry_time, eta_rho) float32 2kB ...
#     ubar_west   (bry_time, eta_rho) float32 2kB ...
#     vbar_west   (bry_time, eta_v) float32 2kB ...
# Attributes:
#     title:                                ROMS boundary forcing file created ...
#     roms_tools_version:                   3.3.0
#     start_time:                           2012-01-01 00:00:00
#     end_time:                             2012-01-02 00:00:00
#     source:                               GLORYS
#     model_reference_date:                 2000-01-01 00:00:00
#     apply_2d_horizontal_fill:             False
#     adjust_depth_for_sea_surface_height:  False
#     theta_s:                              6.0
#     theta_b:                              3.0
#     hc:                                   250.0, <xarray.Dataset> Size: 9MB
# Dimensions:            (bry_time: 12, s_rho: 10, xi_rho: 210, eta_rho: 194)
# Coordinates:
#     month              (bry_time) int32 48B ...
#     abs_time           (bry_time) datetime64[ns] 96B ...
#   * bry_time           (bry_time) float64 96B 15.5 45.0 74.5 ... 319.0 349.5
# Dimensions without coordinates: s_rho, xi_rho, eta_rho
# Data variables: (12/96)
#     PO4_north          (bry_time, s_rho, xi_rho) float32 101kB ...
#     NO3_north          (bry_time, s_rho, xi_rho) float32 101kB ...
#     SiO3_north         (bry_time, s_rho, xi_rho) float32 101kB ...
#     Fe_north           (bry_time, s_rho, xi_rho) float32 101kB ...
#     O2_north           (bry_time, s_rho, xi_rho) float32 101kB ...
#     DIC_north          (bry_time, s_rho, xi_rho) float32 101kB ...
#     ...                 ...
#     diazFe_west        (bry_time, s_rho, eta_rho) float32 93kB ...
#     spCaCO3_west       (bry_time, s_rho, eta_rho) float32 93kB ...
#     zooC_west          (bry_time, s_rho, eta_rho) float32 93kB ...
#     Lig_west           (bry_time, s_rho, eta_rho) float32 93kB ...
#     DIC_ALT_CO2_west   (bry_time, s_rho, eta_rho) float32 93kB ...
#     ALK_ALT_CO2_west   (bry_time, s_rho, eta_rho) float32 93kB ...
# Attributes:
#     title:                                ROMS boundary forcing file created ...
#     roms_tools_version:                   3.3.0
#     start_time:                           2012-01-01 00:00:00
#     end_time:                             2012-01-02 00:00:00
#     source:                               UNIFIED
#     model_reference_date:                 2000-01-01 00:00:00
#     apply_2d_horizontal_fill:             False
#     adjust_depth_for_sea_surface_height:  False
#     theta_s:                              6.0
#     theta_b:                              3.0
#     hc:                                   250.0
#     climatology:                          True]
# ----------------------------------------------------------------------------------------------------
# forcing.tidal
# <xarray.Dataset> Size: 20MB
# Dimensions:  (ntides: 15, eta_rho: 194, xi_rho: 210, xi_u: 209, eta_v: 193)
# Coordinates:
#   * ntides   (ntides) |S3 45B b'm2' b's2' b'n2' b'k2' ... b'ms4' b'2n2' b's1'
#     omega    (ntides) float64 120B ...
# Dimensions without coordinates: eta_rho, xi_rho, xi_u, eta_v
# Data variables:
#     ssh_Re   (ntides, eta_rho, xi_rho) float32 2MB ...
#     ssh_Im   (ntides, eta_rho, xi_rho) float32 2MB ...
#     pot_Re   (ntides, eta_rho, xi_rho) float32 2MB ...
#     pot_Im   (ntides, eta_rho, xi_rho) float32 2MB ...
#     u_Re     (ntides, eta_rho, xi_u) float32 2MB ...
#     u_Im     (ntides, eta_rho, xi_u) float32 2MB ...
#     v_Re     (ntides, eta_v, xi_rho) float32 2MB ...
#     v_Im     (ntides, eta_v, xi_rho) float32 2MB ...
# Attributes:
#     title:                 ROMS tidal forcing created by ROMS-Tools
#     roms_tools_version:    3.3.0
#     source:                TPXO
#     model_reference_date:  2012-01-01 00:00:00
# ----------------------------------------------------------------------------------------------------
# forcing.river
# <xarray.Dataset> Size: 691kB
# Dimensions:           (river_time: 12, nriver: 108, ntracers: 34, eta_rho: 194,
#                        xi_rho: 210)
# Coordinates:
#     month             (river_time) int32 48B ...
#     river_name        (nriver) object 864B ...
#   * nriver            (nriver) int32 432B 1 2 3 4 5 6 ... 104 105 106 107 108
#     abs_time          (river_time) datetime64[ns] 96B ...
#   * river_time        (river_time) float64 96B 15.0 45.0 74.0 ... 319.0 349.0
#     tracer_name       (ntracers) object 272B ...
#     tracer_unit       (ntracers) object 272B ...
#     tracer_long_name  (ntracers) object 272B ...
# Dimensions without coordinates: ntracers, eta_rho, xi_rho
# Data variables:
#     river_volume      (river_time, nriver) float64 10kB ...
#     river_tracer      (river_time, ntracers, nriver) float64 353kB ...
#     river_index       (eta_rho, xi_rho) float32 163kB ...
#     river_fraction    (eta_rho, xi_rho) float32 163kB ...
# Attributes:
#     climatology:  True

# %% [markdown]
# ## Configure Build
#
# Render the Jinja2 templates to generate compile-time and run-time configuration files (`.opt` files, `roms.in`, etc.). This prepares the BUILD stage.

# %%
# configure and build the model
ocn.configure_build(compile_time_settings={}, run_time_settings={})
# Out:
# ROMSSimulation(
# name = cson_roms-marbl_v0.1_test-tiny-abigale,
# directory = /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102,
# start_date = 2012-01-01 00:00:00,
# end_date = 2012-01-02 00:00:00,
# valid_start_date = 2012-01-01 00:00:00,
# valid_end_date = 2012-01-02 00:00:00,
# discretization = ROMSDiscretization(time_step = 1800, n_procs_x = 1, n_procs_y = 1),
# codebase = <ROMSExternalCodeBase instance>,
# runtime_code = <AdditionalCode instance>,
# compile_time_code = <AdditionalCode instance>
# model_grid = <ROMSModelGrid instance>,
# initial_conditions = <ROMSInitialConditions instance>,
# tidal_forcing = <ROMSTidalForcing instance>,
# river_forcing = <ROMSRiverForcing instance>,
# surface_forcing = <list of 2 ROMSSurfaceForcing instances>,
# boundary_forcing = <list of 2 ROMSBoundaryForcing instances>,
# )

# %% [markdown]
# ## Build Model Executable
#
# Compile the ROMS/MARBL model source code to create the executable. This uses the C-Star build system to compile the model with the specified configuration.

# %%
ocn.build()
# Out:
# [INFO] 🛠️ Configuring ROMSSimulation
# [INFO] 🔧 Setting up ROMSExternalCodeBase...
# [INFO] 🔧 Setting up MARBLExternalCodeBase...
# [INFO] 📦 Fetching compile-time code...
# [INFO] 📦 Fetching runtime code...
# [INFO] 📦 Fetching input datasets...
# ROMSSimulation(
# name = cson_roms-marbl_v0.1_test-tiny-abigale,
# directory = /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102,
# start_date = 2012-01-01 00:00:00,
# end_date = 2012-01-02 00:00:00,
# valid_start_date = 2012-01-01 00:00:00,
# valid_end_date = 2012-01-02 00:00:00,
# discretization = ROMSDiscretization(time_step = 1800, n_procs_x = 1, n_procs_y = 1),
# codebase = <ROMSExternalCodeBase instance>,
# runtime_code = <AdditionalCode instance>,
# compile_time_code = <AdditionalCode instance>
# model_grid = <ROMSModelGrid instance>,
# initial_conditions = <ROMSInitialConditions instance>,
# tidal_forcing = <ROMSTidalForcing instance>,
# river_forcing = <ROMSRiverForcing instance>,
# surface_forcing = <list of 2 ROMSSurfaceForcing instances>,
# boundary_forcing = <list of 2 ROMSBoundaryForcing instances>,
# )

# %% [markdown]
# ## Pre-Run Setup
#
# Perform pre-run operations, including partitioning input files for parallel execution if needed.

# %%
# perform partitioning
ocn.pre_run()
# Out:
# [INFO] Partitioning /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_test-tiny-abigale_grid.nc into (1,1)
# [INFO] Partitioning /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_test-tiny-abigale_initial_conditions.nc into (1,1)
# [INFO] Partitioning /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_test-tiny-abigale_tidal.nc into (1,1)
# [INFO] Partitioning /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_test-tiny-abigale_river.nc into (1,1)
# [INFO] Partitioning /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_test-tiny-abigale_boundary-physics_201201.nc into (1,1)
# [INFO] Partitioning /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_test-tiny-abigale_boundary-bgc_clim.nc into (1,1)
# [INFO] Partitioning /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_test-tiny-abigale_surface-physics_201201.nc into (1,1)
# [INFO] Partitioning /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/input_datasets/cson_roms-marbl_v0.1_test-tiny-abigale_surface-bgc_clim.nc into (1,1)

# %% [markdown]
# ## Run Model Simulation
#
# Execute the ROMS model simulation. This runs the model with the configured inputs and settings.

# %%
# run the model
exec_handler = ocn.run()
print(exec_handler)
# Out:
# [INFO] Running srun -n 1 /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/compile_time_code/roms /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/runtime_code/cson_roms-marbl_v0.1_test-tiny-abigale.in
# LocalProcess
# ------------
# Commands: srun -n 1 /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/compile_time_code/roms /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/input/runtime_code/cson_roms-marbl_v0.1_test-tiny-abigale.in
# Run path: /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/output
# Output file: /anvil/scratch/x-awyatt1/cson-forge-run/cson_roms-marbl_v0.1_test-tiny-abigale_20120101-20120102/logs/cson_roms-marbl_v0-1_test-tiny-abigale.out
# Status: running

# %%
# %%time

while not handler.ExecutionStatus.is_terminal(exec_handler.status):
    print("...", end="", flush=True)
    time.sleep(30)

if exec_handler.status == handler.ExecutionStatus.COMPLETED:
    print()
    print("Completed")
    ocn.post_run()
else:
    raise Exception("Model run failed")
# Out:
# CPU times: user 347 μs, sys: 4 μs, total: 351 μs
# Wall time: 262 μs
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\nwhile not handler.ExecutionStatus.is_terminal(exec_handler.status):\n    print("...", end="", flush=True)\n    time.sleep(30)\n\nif exec_handler.status == handler.ExecutionStatus.COMPLETED:\n    print()\n    print("Completed")\n    ocn.post_run()\nelse:\n    raise Exception("Model run failed")\n')
#
# File /anvil/projects/x-ees250129/x-awyatt1/.conda-env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /anvil/projects/x-ees250129/x-awyatt1/.conda-env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1447, in ExecutionMagics.time(self, line, cell, local_ns)
#    1445 if interrupt_occured:
#    1446     if exit_on_interrupt and captured_exception:
# -> 1447         raise captured_exception
#    1448     return
#    1449 return out
#
# File /anvil/projects/x-ees250129/x-awyatt1/.conda-env/lib/python3.13/site-packages/IPython/core/magics/execution.py:1411, in ExecutionMagics.time(self, line, cell, local_ns)
#    1409 st = clock2()
#    1410 try:
# -> 1411     exec(code, glob, local_ns)
#    1412     out = None
#    1413     # multi-line %%time case
#
# File <timed exec>:10
#
# Exception: Model run failed

# %% [markdown]
# ## Visualize Model Output
#
# After the model run completes, you can load and visualize the output data. The code below:
#
# 1. **Finds output files**: Uses `glob` to locate all BGC (biogeochemical) output files in the `JOINED_OUTPUT` directory
# 2. **Opens the dataset**: Uses `xarray.open_mfdataset()` to open multiple NetCDF files as a single dataset
# 3. **Applies land mask**: Masks out land points using the grid's `mask_rho` variable
# 4. **Plots a variable**: Creates a plot of dissolved inorganic carbon (DIC) at the first time step and bottom vertical level (`s_rho=-1`)
#
# The `JOINED_OUTPUT` directory contains the spatially-joined output files created by `post_run()`, which combine partitioned output files from parallel runs into single files.

# %%
import xarray as xr
from glob import glob

files = glob(str(ocn.run_output_dir / "JOINED_OUTPUT" / (ocn.casename + "_bgc.*")))
ds = xr.open_mfdataset(files)
ds = ds.where(ocn.grid.ds.mask_rho)
ds.DIC.isel(time=0, s_rho=-1).plot()

# %% [markdown]
# ## Set Blueprint State
#
# The `set_blueprint_state()` method updates the state of the blueprint, which tracks the workflow stage of the simulation specification. Blueprint states indicate the current stage of the workflow (e.g., "draft", "configured", "ready") and are used by the C-Star orchestration system to manage the simulation lifecycle.
#
# Common blueprint states include:
# - `"draft"`: The blueprint is in development and not yet finalized
# - `"validated"`: The blueprint has been validated
#
# Setting the state to `"draft"` is useful when you want to mark the blueprint as a work-in-progress that may need further modifications before execution.

# %%
ocn.set_blueprint_state(state="draft")
