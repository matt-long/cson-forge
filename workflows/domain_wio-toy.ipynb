# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from subprocess import check_call

from datetime import datetime
from pathlib import Path

import roms_tools as rt

import config
import cson_forge
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %% [markdown]
# ## Define the grid
#
# Specify the grid name and parameters defining its geometry and MPI domain decomposition.

# %%
model_name = "roms-marbl"
grid_name = "wio-toy"

start_time = datetime(2012, 1, 1)
end_time = datetime(2012, 1, 2)

boundaries={
        "south": True,
        "east": True,
        "north": True,
        "west": True, 
    }

np_eta = 5 # number of partitions in eta (y) 
np_xi = 2 # number of partitions in xi (x) 

grid_kwargs = dict(
    nx=20,           # number of grid points in x-direction
    ny=20,           # number of grid points in y-direction
    N=10,             # number of vertical layers
    size_x=8000,       # domain size in x-direction (km)
    size_y=8000,       # domain size in y-direction (km)
    center_lon=60.0,    # center longitude (E)
    center_lat=-4.0,    # center latitude (S)
    rot=0,            # no rotation
)

ocn = cson_forge.OcnModel(
    model_name=model_name,
    grid_name=grid_name,
    grid_kwargs=grid_kwargs,
    boundaries=boundaries,    
    start_time=start_time,
    end_time=end_time,
    np_eta=np_eta,
    np_xi=np_xi,
)
ocn.grid.plot()

# %%
ocn.prepare_source_data(clobber=False)
# Out:
# ⬇️  Downloading GLORYS_REGIONAL for 2012-01-01 → cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_wio-toy_20120101.nc
# INFO - 2025-11-21T18:30:27Z - Selected dataset version: "202311"
# 2025-11-21 18:30:27 - INFO - Selected dataset version: "202311"
# INFO - 2025-11-21T18:30:27Z - Selected dataset part: "default"
# 2025-11-21 18:30:27 - INFO - Selected dataset part: "default"
# INFO - 2025-11-21T18:30:33Z - Starting download. Please wait...
# 2025-11-21 18:30:33 - INFO - Starting download. Please wait...
#   0%|          | 0/74 [00:00<?, ?it/s]
# 2025-11-21 18:30:47 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:30:47 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:30:47 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:30:47 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:30:47 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:30:47 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# INFO - 2025-11-21T18:30:47Z - Successfully downloaded to /Users/mclong/cson-forge-data/source-data/GLORYS_REGIONAL/cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_wio-toy_20120101.nc
# 2025-11-21 18:30:47 - INFO - Successfully downloaded to /Users/mclong/cson-forge-data/source-data/GLORYS_REGIONAL/cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_wio-toy_20120101.nc
# ⬇️  Downloading GLORYS_REGIONAL for 2012-01-02 → cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_wio-toy_20120102.nc
# INFO - 2025-11-21T18:30:50Z - Selected dataset version: "202311"
# 2025-11-21 18:30:50 - INFO - Selected dataset version: "202311"
# INFO - 2025-11-21T18:30:50Z - Selected dataset part: "default"
# 2025-11-21 18:30:50 - INFO - Selected dataset part: "default"
# INFO - 2025-11-21T18:30:56Z - Starting download. Please wait...
# 2025-11-21 18:30:56 - INFO - Starting download. Please wait...
#   0%|          | 0/74 [00:00<?, ?it/s]
# 2025-11-21 18:31:10 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:31:10 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:31:10 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:31:10 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:31:10 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 18:31:10 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# INFO - 2025-11-21T18:31:11Z - Successfully downloaded to /Users/mclong/cson-forge-data/source-data/GLORYS_REGIONAL/cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_wio-toy_20120102.nc
# 2025-11-21 18:31:11 - INFO - Successfully downloaded to /Users/mclong/cson-forge-data/source-data/GLORYS_REGIONAL/cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_wio-toy_20120102.nc
# ✔️  TPXO dataset verified at: /Users/mclong/cson-forge-data/source-data/TPXO/TPXO10.v2
# ✔️  Using existing BGC dataset: /Users/mclong/cson-forge-data/source-data/UNIFIED_BGC/BGCdataset.nc

# %%
inputs = ocn.generate_inputs(clobber=True)
# Out:
# 2025-11-21 18:31:11 - INFO - Writing the following NetCDF files:
# /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy/roms_grid.nc
# 2025-11-21 18:31:11 - INFO - Sea surface height will NOT be used to adjust depth coordinates.
# ⚠️  Clobber=True: removing 2 existing .nc files in /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy...
#
# ▶️  [1/9] Writing ROMS grid...
#
# ▶️  [2/9] Generating initial conditions...
# 2025-11-21 18:31:16 - INFO - Writing the following NetCDF files:
# /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy/roms_initial_conditions.nc
# [##################################      ] | 85% Completed | 2.93 s ms
# /Users/mclong/miniconda3/envs/romstools-test/lib/python3.13/site-packages/dask/array/reductions.py:325: RuntimeWarning: All-NaN slice encountered
#   return np.nanmax(x_chunk, axis=axis, keepdims=keepdims)
# [########################################] | 100% Completed | 26.11 s
# 2025-11-21 18:31:42 - INFO - No path specified for ERA5 source; defaulting to ARCO ERA5 dataset on Google Cloud.
# ▶️  [3/9] Generating surface forcing (physics)...
# 2025-11-21 18:33:06 - INFO - Data will be interpolated onto the fine grid. Remember to set `interp_frc = 0` in your `bulk_frc.opt` ROMS option file.
# 2025-11-21 18:33:15 - INFO - Writing the following NetCDF files:
# /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy/roms_surface_forcing_201201.nc
# [########################################] | 100% Completed | 8.22 sms
# 2025-11-21 18:33:28 - INFO - Data will be interpolated onto the fine grid. Remember to set `interp_frc = 0` in your `bgc.opt` ROMS option file.
# ▶️  [4/9] Generating surface forcing (BGC)...
# 2025-11-21 18:33:28 - INFO - Writing the following NetCDF files:
# /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy/roms_surface_forcing_bgc_clim.nc
# [########################################] | 100% Completed | 104.39 ms
# 2025-11-21 18:33:28 - INFO - Sea surface height will NOT be used to adjust depth coordinates.
# ▶️  [5/9] Generating boundary forcing (physics)...
# 2025-11-21 18:33:35 - INFO - Writing the following NetCDF files:
# /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy/roms_boundary_forcing_201201.nc
# [########################################] | 100% Completed | 1.97 sms
# 2025-11-21 18:33:37 - INFO - Sea surface height will NOT be used to adjust depth coordinates.
# ▶️  [6/9] Generating boundary forcing (BGC)...
# 2025-11-21 18:33:39 - INFO - Writing the following NetCDF files:
# /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy/roms_boundary_forcing_bgc_clim.nc
# [########################################] | 100% Completed | 9.96 ss
#
# ▶️  [7/9] Generating tidal forcing...
# 2025-11-21 18:33:53 - INFO - Writing the following NetCDF files:
# /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy/roms_tidal_forcing.nc
# [########################################] | 100% Completed | 3.85 sms
#
# ▶️  [8/9] Generating river forcing...
# 2025-11-21 18:33:57 - INFO - No river indices provided. Identify all rivers within the ROMS domain and assign each of them to the nearest coastal point.
# 2025-11-21 18:33:57 - INFO - Compute climatology for river forcing.
# 2025-11-21 18:33:57 - INFO - Creating 14 synthetic river(s) to handle overlapping entries.
# 2025-11-21 18:33:57 - WARNING - NaNs detected in 'river_volume' and set to zero. This may indicate missing river data and affect model accuracy.
# 2025-11-21 18:33:57 - INFO - Writing the following NetCDF files:
# /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy/roms_rivers.nc
# ▶️  [9/9] Partitioning input files across tiles...
#
# ✅ All input files generated and partitioned.
#
# 📄  Wrote ROMSInputs blueprint to /Users/mclong/codes/cson-forge/workflows/blueprints/roms-marbl_wio-toy/blueprint_roms-marbl-wio-toy.yml

# %% [markdown]
# ### Quick look at some forcing

# %%
inputs["initial_conditions"].plot("DIC", s=-1)
# Out:
# [########################################] | 100% Completed | 208.73 ms

# %%
inputs["surface_forcing"].plot("uwnd", time=0)
# Out:
# [########################################] | 100% Completed | 521.53 ms

# %% [markdown]
# ## Build the model
#
# Apply templating to source code and input files, then build the model

# %%
parameters = {
    "param.opt": dict(NP_XI=np_xi, NP_ETA=np_eta, NX=ocn.grid.nx, NY=ocn.grid.ny, NK=ocn.grid.N),
    "river_frc.opt": dict(nriv=inputs["rivers"].ds.sizes["nriver"]),
}

ocn.build(parameters, clean=True)
# Out:
# Build token: 20251121T183402Z-3436f2ec
# Building roms-marbl for grid: wio-toy
# roms-marbl opt_base_dir : /Users/mclong/codes/cson-forge/workflows/model-configs/opt_base/opt_base_roms-marbl-cson-default
# ROMS opt_dir      : /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/opt
# ROMS build_dir    : /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/bld
# Input data path   : /Users/mclong/cson-forge-data/input-data/roms-marbl_wio-toy
# ROMS_ROOT         : /Users/mclong/cson-forge-data/codes/ucla-roms
# MARBL_ROOT        : /Users/mclong/cson-forge-data/codes/MARBL
# Conda env         : roms_env
# Logs              : /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/logs
# Conda env 'roms_env' already exists.
# Using compiler kind: gnu
# Found 11 existing build(s) in /Users/mclong/codes/cson-forge/workflows/builds.yml.
# Matching build found: token=20251121T182432Z-48104304
#   -> using existing executable at: /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/exe/roms-marbl-wio-toy-20251121T182432Z-48104304
# Clean build requested; attempting to remove existing executable: /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/exe/roms-marbl-wio-toy-20251121T182432Z-48104304
#   -> removed existing executable.
# ROMS repo already present at /Users/mclong/cson-forge-data/codes/ucla-roms
# MARBL repo already present at /Users/mclong/cson-forge-data/codes/MARBL
# Checking out MARBL marbl0.45.0
# # packages in environment at /Users/mclong/miniconda3/envs/roms_env:
# #
# # Name                         Version          Build                  Channel
# blosc                          1.21.6           h7dd00d9_1             conda-forge
# bzip2                          1.0.8            hd037594_8             conda-forge
# c-ares                         1.34.5           h5505292_0             conda-forge
# c-compiler                     1.11.0           h61f9b84_0             conda-forge
# ca-certificates                2025.10.5        hbd8a1cb_0             conda-forge
# cctools                        1024.3           hd01ab73_9             conda-forge
# cctools_osx-arm64              1024.3           llvm19_1_h8c76c84_9    conda-forge
# clang                          19.1.7           default_hf9bcbb7_5     conda-forge
# clang-19                       19.1.7           default_h73dfc95_5     conda-forge
# clang_impl_osx-arm64           19.1.7           h76e6a08_25            conda-forge
# clang_osx-arm64                19.1.7           h07b0088_25            conda-forge
# clangxx                        19.1.7           default_h36137df_5     conda-forge
# clangxx_impl_osx-arm64         19.1.7           h276745f_25            conda-forge
# clangxx_osx-arm64              19.1.7           h07b0088_25            conda-forge
# compiler-rt                    19.1.7           h855ad52_1             conda-forge
# compiler-rt_osx-arm64          19.1.7           he32a8d3_1             conda-forge
# compilers                      1.11.0           hce30654_0             conda-forge
# cxx-compiler                   1.11.0           h88570a1_0             conda-forge
# fortran-compiler               1.11.0           h81a4f41_0             conda-forge
# gfortran                       14.3.0           h3ef1dbf_0             conda-forge
# gfortran_impl_osx-arm64        14.3.0           h6d03799_1             conda-forge
# gfortran_osx-arm64             14.3.0           h3c33bd0_0             conda-forge
# gmp                            6.3.0            h7bae524_2             conda-forge
# hdf4                           4.2.15           h2ee6834_7             conda-forge
# hdf5                           1.14.6           nompi_he65715a_103     conda-forge
# icu                            75.1             hfee45f7_0             conda-forge
# isl                            0.26             imath32_h347afa1_101   conda-forge
# krb5                           1.21.3           h237132a_0             conda-forge
# ld64                           955.13           he86490a_9             conda-forge
# ld64_osx-arm64                 955.13           llvm19_1_h6922315_9    conda-forge
# libaec                         1.1.4            h51d1e36_0             conda-forge
# libblas                        3.9.0            38_h51639a9_openblas   conda-forge
# libcblas                       3.9.0            38_hb0561ab_openblas   conda-forge
# libclang-cpp19.1               19.1.7           default_h73dfc95_5     conda-forge
# libcurl                        8.17.0           hdece5d2_0             conda-forge
# libcxx                         21.1.5           hf598326_0             conda-forge
# libcxx-devel                   19.1.7           h6dc3340_1             conda-forge
# libedit                        3.1.20250104     pl5321hafb1f1b_0       conda-forge
# libev                          4.33             h93a5062_2             conda-forge
# libexpat                       2.7.1            hec049ff_0             conda-forge
# libfabric                      2.3.1            hce30654_1             conda-forge
# libfabric1                     2.3.1            hc919400_1             conda-forge
# libffi                         3.5.2            he5f378a_0             conda-forge
# libgfortran                    15.2.0           hfcf01ff_1             conda-forge
# libgfortran-devel_osx-arm64    14.3.0           hc965647_1             conda-forge
# libgfortran5                   15.2.0           h742603c_1             conda-forge
# libhwloc                       2.12.1           default_h48b22c3_1002  conda-forge
# libiconv                       1.18             h23cfdf5_2             conda-forge
# libjpeg-turbo                  3.1.2            hc919400_0             conda-forge
# liblapack                      3.9.0            38_hd9741b5_openblas   conda-forge
# libllvm19                      19.1.7           h8e0c9ce_2             conda-forge
# liblzma                        5.8.1            h39f12f2_2             conda-forge
# libnetcdf                      4.9.3            nompi_h80c4520_103     conda-forge
# libnghttp2                     1.67.0           hc438710_0             conda-forge
# libopenblas                    0.3.30           openmp_ha158390_3      conda-forge
# libsqlite                      3.51.0           h8adb53f_0             conda-forge
# libssh2                        1.11.1           h1590b86_0             conda-forge
# libxml2                        2.15.1           h9329255_0             conda-forge
# libxml2-16                     2.15.1           h0ff4647_0             conda-forge
# libzip                         1.11.2           h1336266_0             conda-forge
# libzlib                        1.3.1            h8359307_2             conda-forge
# llvm-openmp                    21.1.5           h4a912ad_0             conda-forge
# llvm-tools                     19.1.7           h855ad52_2             conda-forge
# llvm-tools-19                  19.1.7           h91fd4e7_2             conda-forge
# lz4-c                          1.10.0           h286801f_1             conda-forge
# mpc                            1.3.1            h8f1351a_1             conda-forge
# mpfr                           4.2.1            hb693164_3             conda-forge
# mpi                            1.0.1            mpich                  conda-forge
# mpich                          4.3.2            hf5485c1_100           conda-forge
# ncurses                        6.5              h5e97a16_3             conda-forge
# netcdf-fortran                 4.6.2            nompi_h799d18b_102     conda-forge
# numpy                          2.2.6            py310h4d83441_0        conda-forge
# openssl                        3.5.4            h5503f6c_0             conda-forge
# pip                            25.3             pyh8b19718_0           conda-forge
# python                         3.10.19          hcd7f573_2_cpython     conda-forge
# python_abi                     3.10             8_cp310                conda-forge
# readline                       8.2              h1d1bf99_2             conda-forge
# setuptools                     80.9.0           pyhff2d567_0           conda-forge
# sigtool                        0.1.3            h44b9a77_0             conda-forge
# snappy                         1.2.2            hd121638_0             conda-forge
# tapi                           1300.6.5         h03f4b80_0             conda-forge
# tk                             8.6.13           h892fb3f_2             conda-forge
# tzdata                         2025b            h78e105d_0             conda-forge
# wheel                          0.45.1           pyhd8ed1ab_1           conda-forge
# zlib                           1.3.1            h8359307_2             conda-forge
# zstd                           1.5.7            h6491c7d_2             conda-forge
# [Clean] MARBL/src ...
# rm -f /Users/mclong/cson-forge-data/codes/MARBL/tests/obj/*/shared_deps.d /Users/mclong/cson-forge-data/codes/MARBL/lib/libmarbl*.a
# find /Users/mclong/cson-forge-data/codes/MARBL/tests/obj -maxdepth 2 -name marbl_*.o | xargs rm -f
# find /Users/mclong/cson-forge-data/codes/MARBL/tests/obj -maxdepth 2 -name marbl_*.mod | xargs rm -f
# find /Users/mclong/cson-forge-data/codes/MARBL/include -maxdepth 2 -name marbl_*.mod | xargs rm -f
#
# [Build MARBL (compiler: gnu)] starting...
# [Build MARBL (compiler: gnu)] OK
# [Clean] NHMG/src ...
# INFO: Automatically selected MPI_WRAPPER=mpifort based on COMPILER=gnu
# rm -f ../lib/libnhmg.a mg_autotune.o mg_cst.o mg_gather.o mg_grids.o mg_horiz_grids.o mg_intergrids.o mg_mpi.o mg_mpi_exchange.o mg_namelist.o mg_netcdf_out.o mg_netcdf_out_true.o mg_projection.o mg_relax.o mg_solvers.o mg_tictoc.o mg_vert_grids.o nhmg.o nhmg_debug.o *.mod
#
# [Build NHMG/src] starting...
# [Build NHMG/src] OK
# [Clean] Tools-Roms ...
# INFO: Automatically selected MPI_WRAPPER=mpifort based on COMPILER=gnu
# MAKING ROMS TOOLS:
# /bin/rm -f *.fpp *.o *.a *.s *.trace *.mod
#
# [Build Tools-Roms] starting...
# [Build Tools-Roms] OK
# [Render] Clearing existing opt_dir: /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/opt
# [Render] Rendering template: param.opt
# [Render] Rendering template: river_frc.opt
# [Clean] ROMS (/Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/opt) ...
# make: Nothing to be done for `clean'.
#
# [Build ROMS (/Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/bld_tmp)] starting...
# [Build ROMS (/Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/bld_tmp)] OK
# roms-marbl executable -> /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/exe/roms-marbl-wio-toy-20251121T183402Z-3436f2ec
#
# ✅ All builds completed.
# • Build token:      20251121T183402Z-3436f2ec
# • ROMS root:        /Users/mclong/cson-forge-data/codes/ucla-roms
# • MARBL root:       /Users/mclong/cson-forge-data/codes/MARBL
# • App root:         /Users/mclong/codes/cson-forge/workflows/model-configs/opt_base/opt_base_roms-marbl-cson-default
# • Logs:             /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/logs
# • ROMS exe:         /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/exe/roms-marbl-wio-toy-20251121T183402Z-3436f2ec
# • builds.yaml:      /Users/mclong/codes/cson-forge/workflows/builds.yml
# PosixPath('/Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/exe/roms-marbl-wio-toy-20251121T183402Z-3436f2ec')

# %%
ocn.run(case="test.001")
# Out:
# Copying settings input files from /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/opt to /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001:
#   roms.in -> /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001/roms.in
#   marbl_in -> /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001/marbl_in
#   marbl_tracer_output_list -> /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001/marbl_tracer_output_list
# Rendering master settings file: roms.in
#   Rendered roms.in -> /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001/roms.in
# Copying executable to run directory:
#   /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_wio-toy/exe/roms-marbl-wio-toy-20251121T183402Z-3436f2ec -> /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001/roms-marbl-wio-toy-20251121T183402Z-3436f2ec
# Running model locally: mpirun -n 10 /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001/roms-marbl-wio-toy-20251121T183402Z-3436f2ec roms.in > /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001/test.001.20251121T202147Z.log 2>&1
# Working directory: /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001
# Log file: /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001/test.001.20251121T202147Z.log
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 ocn.run(case="test.001")
#
# File ~/codes/cson-forge/workflows/cson_forge.py:1884, in OcnModel.run(self, case, cluster_type, account, queue, wallclock_time)
#    1878 if self.executable is None:
#    1879     raise RuntimeError(
#    1880         "You must call OcnModel.build() "
#    1881         "before running the model."
#    1882     )
# -> 1884 run(
#    1885     model_spec=self.spec,
#    1886     grid_name=self.grid_name,
#    1887     case=case,
#    1888     input_data_path=self.inputs.input_data_dir,
#    1889     executable_path=self.executable,
#    1890     run_command=self._run_command,
#    1891     inputs=self.inputs.inputs,
#    1892     cluster_type=cluster_type,
#    1893     account=account,
#    1894     queue=queue,
#    1895     wallclock_time=wallclock_time,
#    1896 )
#
# File ~/codes/cson-forge/workflows/cson_forge.py:101, in run(model_spec, grid_name, case, input_data_path, executable_path, run_command, inputs, cluster_type, account, queue, wallclock_time, log_func)
#      97         return block.get("name")
#      98     return None
# --> 101 def _dataset_keys_from_inputs(inputs: Dict[str, Dict[str, Any]]) -> set[str]:
#     102     dataset_keys: set[str] = set()
#     103     for cfg in inputs.values():
#
# RuntimeError: Model run failed with exit code 11. See log file for details: /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_wio-toy/test.001/test.001.20251121T202147Z.log
