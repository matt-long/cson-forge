# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from glob import glob

from datetime import datetime
from pathlib import Path

import gdown
import copernicusmarine

import roms_tools as rt
import config
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
clobber = False

grid_name = "wio-toy"

start_time = datetime(2012, 1, 1)
end_time = datetime(2012, 2, 1)

# %%
os.environ["CONFIG_ROOT"] = str(config.model_config)
os.environ["GRID_NAME"] = grid_name

# %%
# %%bash
# ./build.roms-marbl.sh --grid-name ${GRID_NAME} --config-root ${CONFIG_ROOT} --clean
# Out:
# HEAD is now at 6e6b2f7 Merge branch 'add_abio' into development
# [Clean] MARBL/src ...
# rm -f /Users/mclong/codes/MARBL/tests/obj/*/shared_deps.d /Users/mclong/codes/MARBL/lib/libmarbl*.a
# find /Users/mclong/codes/MARBL/tests/obj -maxdepth 2 -name marbl_*.o | xargs rm -f
# find /Users/mclong/codes/MARBL/tests/obj -maxdepth 2 -name marbl_*.mod | xargs rm -f
# find /Users/mclong/codes/MARBL/include -maxdepth 2 -name marbl_*.mod | xargs rm -f
# [Build MARBL (compiler: gnu)] starting...
# [Build MARBL (compiler: gnu)] OK
# [Clean] NHMG/src ...
# INFO: Automatically selected MPI_WRAPPER=mpifort based on COMPILER=gnu
# rm -f ../lib/libnhmg.a mg_autotune.o mg_cst.o mg_gather.o mg_grids.o mg_horiz_grids.o mg_intergrids.o mg_mpi.o mg_mpi_exchange.o mg_namelist.o mg_netcdf_out.o mg_netcdf_out_true.o mg_projection.o mg_relax.o mg_solvers.o mg_tictoc.o mg_vert_grids.o nhmg.o nhmg_debug.o *.mod
# [Build NHMG/src] starting...
# [Build NHMG/src] OK
# [Clean] Tools-Roms ...
# INFO: Automatically selected MPI_WRAPPER=mpifort based on COMPILER=gnu
# MAKING ROMS TOOLS:
# /bin/rm -f *.fpp *.o *.a *.s *.trace *.mod
# [Build Tools-Roms] starting...
# [Build Tools-Roms] OK
# [Clean] ROMS (/Users/mclong/codes/cson-forge/workflows/model-configs/roms-marbl-cson-default) ...
# fatal: ambiguous argument 'HEAD': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'
# make: Nothing to be done for `clean'.
# [Build ROMS (/Users/mclong/codes/cson-forge/workflows/model-configs/roms-marbl-cson-default)] starting...
# [Build ROMS (/Users/mclong/codes/cson-forge/workflows/model-configs/roms-marbl-cson-default)] OK
#
# ✅ All builds completed.
# • ROMS root:        /Users/mclong/codes/ucla-roms
# • MARBL root:       /Users/mclong/codes/MARBL
# • App root:         /Users/mclong/codes/cson-forge/workflows/model-configs/roms-marbl-cson-default
# • Logs:             /Users/mclong/codes/cson-forge/workflows/logs
#
# To run your case:
#   cd "/Users/mclong/codes/cson-forge/workflows/model-configs/roms-marbl-cson-default"
#   mpirun -n 6 ./roms <your_input>.in
