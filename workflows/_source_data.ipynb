# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datetime import datetime
import source_data
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
start_time = datetime(2012, 1, 1)
end_time = datetime(2012, 1, 2)

src_data = source_data.SourceData(
    datasets=["GLORYS", "SRTM"],
    start_time=start_time,
    end_time=end_time,
    clobber=False,
).prepare_all()
# Out:
# ['GLORYS_GLOBAL']
# ⬇️  Downloading GLORYS_GLOBAL for 2012-01-01 → cmems_mod_glo_phy_my_0.083deg_P1D-m_GLOBAL_20120101.nc
# INFO - 2025-11-21T05:26:56Z - Selected dataset version: "202311"
# 2025-11-21 05:26:56 - INFO - Selected dataset version: "202311"
# INFO - 2025-11-21T05:26:56Z - Selected dataset part: "default"
# 2025-11-21 05:26:56 - INFO - Selected dataset part: "default"
# INFO - 2025-11-21T05:26:58Z - Starting download. Please wait...
# 2025-11-21 05:26:58 - INFO - Starting download. Please wait...
#   0%|          | 0/113 [00:00<?, ?it/s]
# 2025-11-21 05:27:18 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 05:27:18 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# 2025-11-21 05:27:18 - WARNING - Connection pool is full, discarding connection: s3.waw3-1.cloudferro.com. Connection pool size: 10
# ...
